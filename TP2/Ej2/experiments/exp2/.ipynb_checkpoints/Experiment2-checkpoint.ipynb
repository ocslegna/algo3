# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
df_rand = pd.read_csv('exp2random.csv', delimiter=';')
df_comp = pd.read_csv('exp2complete.csv', delimiter=';')
df_spar = pd.read_csv('exp2sparse.csv', delimiter=';')
df_nfijo = pd.read_csv('exp2nfijo.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4610cce09198> in <module>()
#       2 df_comp = pd.read_csv('exp2complete.csv', delimiter=';')
#       3 df_spar = pd.read_csv('exp2sparse.csv', delimiter=';')
# ----> 4 df_nfijo = pd.read_csv('exp2nfijo.csv', delimiter=';')
#
# /usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# /usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'exp2nfijo.csv' does not exist

# %%
print("Frente a grafos Completos")
ax = plt.gca()
for title, group in df_comp.groupby('modo'):
    group = group.groupby('vertices').median().reset_index()
    group.plot(x='vertices', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')
plt.show()
# Out:
# Frente a grafos Completos

# %%
print("Frente a grafos esparsos")
ax = plt.gca()
for title, group in df_spar.groupby('modo'):
    group = group.groupby('vertices').median().reset_index()
    group.plot(x='vertices', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')
plt.show()
# Out:
# Frente a grafos esparsos

# %%
print("Frente a grafos de cantidad de aristas random")
ax = plt.gca()
# Plotting random graphs
#title_label = ('m variable')
for title, group in df_rand.groupby('modo'):
    group = group.groupby('vertices').median().reset_index()
    group.plot(x='vertices', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')

plt.show()
# Out:
# Frente a grafos de cantidad de aristas random

# %%
print("Coeficientes de pearson para versión completos")
for title, group in df_comp.groupby('modo'):
    group = group.groupby('vertices').median().reset_index()
    group.plot(x='vertices', y='duracion', label=title, ax=ax)

t = np.arange(10,501)
tnlogn = []

for i in range(0, len(t)):
    tnlogn.append(math.log(t[i], 10))

lin = np.corrcoef(group['duracion'], t)[0,1]
supralin = np.corrcoef(group['duracion'], t**1.75)[0,1] 
cuad = np.corrcoef(group['duracion'], t**2)[0,1]
cub = np.corrcoef(group['duracion'], t**3)[0,1]
cuart = np.corrcoef(group['duracion'], t**4)[0,1]
nlogn = np.corrcoef(group['duracion'], tnlogn)[0,1]
print(lin)
print(supralin)
print(cuad)
print(cub)
print(cuart)
print(nlogn)

print(str(round(lin,6)) + " & " + str(round(supralin,6)) + " & " + str(round(cuad,6)) + " & " + str(round(cub,6)) + " & " + str(round(cuart,6)) + " & " + str(round(nlogn,6)) )
# Out:
# Coeficientes de pearson para versión completos
# 0.977091961241
# 0.999712956985
# 0.999545775379
# 0.981303199417
# 0.951086218417
# 0.826940032752
# 0.977092 & 0.999713 & 0.999546 & 0.981303 & 0.951086 & 0.82694

# %%
print("Coeficientes de pearson para versión esparsos")
for title, group in df_spar.groupby('modo'):
    group = group.groupby('vertices').median().reset_index()
    group.plot(x='vertices', y='duracion', label=title, ax=ax)
#print(group)
t = np.arange(10,501)
tnlogn = []

for i in range(0, len(t)):
    tnlogn.append(math.log(t[i], 10))

lin = np.corrcoef(group['duracion'], t)[0,1]
supralin = np.corrcoef(group['duracion'], t**1.75)[0,1] 
cuad = np.corrcoef(group['duracion'], t**2)[0,1]
cub = np.corrcoef(group['duracion'], t**3)[0,1]
cuart = np.corrcoef(group['duracion'], t**4)[0,1]
nlogn = np.corrcoef(group['duracion'], tnlogn)[0,1]

print(lin)
print(supralin)
print(cuad)
print(cub)
print(cuart)
print(nlogn)

#print(round(lin, 2))
print(str(round(lin,6)) + " & " + str(round(supralin,6)) + " & " + str(round(cuad,6)) + " & " + str(round(cub,6)) + " & " + str(round(cuart,6)) + " & " + str(round(nlogn,6)) )
# Out:
# Coeficientes de pearson para versión esparsos
# 0.973942373796
# 0.983922130771
# 0.980314740524
# 0.951548891991
# 0.914578789232
# 0.84361661791
# 0.973942 & 0.983922 & 0.980315 & 0.951549 & 0.914579 & 0.843617

# %%
print("Coeficientes de pearson para versión random")
for title, group in df_rand.groupby('modo'):
    group = group.groupby('vertices').median().reset_index()
    group.plot(x='vertices', y='duracion', label=title, ax=ax)
#print(group)
t = np.arange(10,501)
tnlogn = []

for i in range(0, len(t)):
    tnlogn.append(math.log(t[i], 10))

lin = np.corrcoef(group['duracion'], t)[0,1]
supralin = np.corrcoef(group['duracion'], t**1.75)[0,1] 
cuad = np.corrcoef(group['duracion'], t**2)[0,1]
cub = np.corrcoef(group['duracion'], t**3)[0,1]
cuart = np.corrcoef(group['duracion'], t**4)[0,1]
nlogn = np.corrcoef(group['duracion'], tnlogn)[0,1]

print(lin)
print(supralin)
print(cuad)
print(cub)
print(cuart)
print(nlogn)

#print(round(lin, 2))
print(str(round(lin,6)) + " & " + str(round(supralin,6)) + " & " + str(round(cuad,6)) + " & " + str(round(cub,6)) + " & " + str(round(cuart,6)) + " & " + str(round(nlogn,6)) )
# Out:
# Coeficientes de pearson para versión random
# 0.956646513199
# 0.975154303972
# 0.973898538479
# 0.95223663401
# 0.919584296288
# 0.814646670729
# 0.956647 & 0.975154 & 0.973899 & 0.952237 & 0.919584 & 0.814647

# %%
print("Calculando densidad de grafos esparsos")
m = df_spar['aristas']
n = df_spar['vertices']
d = 2*m/(n*(n-1))
print("Mínima densidad: "+ str(min(d)))
print("Máxima densidad: "+ str(max(d)))
# Out:
# Calculando densidad de grafos esparsos
# Mínima densidad: 0.0476706392199
# Máxima densidad: 0.244444444444

# %%
print("Parte b de la experimentación, n = 500, m variable")
ax = plt.gca()
for title, group in df_nfijo.groupby('modo'):
    group = group.groupby('aristas').median().reset_index()
    group.plot(x='aristas', y='duracion', label=title, ax=ax, linestyle=':')
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')

plt.axvline(x=95000, color = 'red', linestyle = ':')
plt.text(93000,8000000,'m = 95000',rotation=90)
plt.axvline(x=97500, color = 'red', linestyle = ':')
plt.text(98500,8000000,'m = 97500',rotation=90)


plt.show()
# Out:
# Parte b de la experimentación, n = 500, m variable

# %%
print("Calculando densidad de grafos random")
m = df_rand['aristas']
n = df_rand['vertices']
d = 2*m/(n*(n-1))
print("Máxima  densidad: "+ str(max(d)))
print("Mínima  densidad: "+ str(min(d)))
print("Media   densidad: "+ str(d.mean()))
print("Mediana densidad: "+ str(d.median()))
# Out:
# Calculando densidad de grafos random
# Máxima  densidad: 0.444444444444
# Mínima  densidad: 0.0
# Media   densidad: 0.00444444444444
# Mediana densidad: 0.0002673082063619353

# %%
print("Parte b de la experimentación, n = 500, m variable")
ax = plt.gca()
for title, group in df_nfijo.groupby('modo'):
    group = group.groupby('aristas').median().reset_index()
    group.plot(x='aristas', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
#print("Current size:", fig_size)
 
# Set figure width to 12 and height to 9

fig_size[0] = 10
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size
plt.axvline(x=95000, color = 'red', linestyle = ':')
plt.text(93000,8000000,'m = 95000',rotation=90)
#plt.axvline(x=97500, color = 'red', linestyle = ':')
#plt.text(98500,8000000,'m = 97500',rotation=90)


plt.show()
# Out:
# Parte b de la experimentación, n = 500, m variable

# %%
df_nfijo = pd.read_csv('exp2nfijo200.csv', delimiter=';')
print("Parte b de la experimentación, n = 200, m variable")
ax = plt.gca()
for title, group in df_nfijo.groupby('modo'):
    group = group.groupby('aristas').median().reset_index()
    group.plot(x='aristas', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
#print("Current size:", fig_size)
 
# Set figure width to 12 and height to 9

#fig_size[0] = 10
#fig_size[1] = 8

#plt.rcParams["figure.figsize"] = fig_size
plt.axvline(x=13500, color = 'red', linestyle = ':')
plt.text(12800,4000000,'m = 95000',rotation=90)


plt.show()
# Out:
# Parte b de la experimentación, n = 200, m variable

# %%
df_nfijo = pd.read_csv('exp2nfijo50.csv', delimiter=';')
print("Parte b de la experimentación, n = 50, m variable")
ax = plt.gca()
for title, group in df_nfijo.groupby('modo'):
    group = group.groupby('aristas').median().reset_index()
    group.plot(x='aristas', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
#print("Current size:", fig_size)
 
# Set figure width to 12 and height to 9

#fig_size[0] = 10
#fig_size[1] = 8

#plt.rcParams["figure.figsize"] = fig_size
#plt.axvline(x=13500, color = 'red', linestyle = ':')
#plt.text(93000,8000000,'m = 95000',rotation=90)


plt.show()
# Out:
# Parte b de la experimentación, n = 500, m variable

# %%
df_nfijo = pd.read_csv('exp2nfijo100.csv', delimiter=';')
print("Parte b de la experimentación, n = 100, m variable")
ax = plt.gca()
for title, group in df_nfijo.groupby('modo'):
    group = group.groupby('aristas').median().reset_index()
    group.plot(x='aristas', y='duracion', label=title, ax=ax)
plt.ylabel('ticks de reloj')
plt.xlabel('cantidad de vértices')

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
#print("Current size:", fig_size)
 
# Set figure width to 12 and height to 9

#fig_size[0] = 10
#fig_size[1] = 8

#plt.rcParams["figure.figsize"] = fig_size
plt.axvline(x=2500, color = 'red', linestyle = ':')


plt.show()
# Out:
# Parte b de la experimentación, n = 500, m variable
